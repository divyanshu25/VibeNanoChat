# %%
from src.gpt_2.gpt2_model import GPT, GPTConfig
import matplotlib.pyplot as plt
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
checkpoint_path = "/sensei-fs/users/divgoyal/nanogpt/pretrain_checkpoints/model_checkpoint_global37953_pretraining.pt"
checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
# Load model state

model = GPT(GPTConfig())
model.load_state_dict(checkpoint["model"])
# Out:
# <All keys matched successfully>

# %%
wpe = model.transformer.wpe

# %%
wpe_weights = wpe.weight.data.cpu().numpy()

plt.plot(wpe_weights[:, 100])
plt.plot(wpe_weights[:, 150])
plt.plot(wpe_weights[:, 200])
plt.plot(wpe_weights[:, 250])
plt.plot(wpe_weights[:, 300])
plt.plot(wpe_weights[:, 350])
plt.plot(wpe_weights[:, 400])
plt.plot(wpe_weights[:, 450])
plt.plot(wpe_weights[:, 500])
plt.plot(wpe_weights[:, 550])
plt.plot(wpe_weights[:, 600])
plt.show()

# %%
wpe_weights = wpe.weight.data.cpu().numpy()

plt.plot(wpe_weights)
plt.show()
